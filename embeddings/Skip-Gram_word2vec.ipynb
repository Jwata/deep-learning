# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

word_counts = Counter(int_words)
total_counts = len(int_words)

def word_frequency(int_word):
    word_count = word_counts[int_word]
    return word_count / total_counts

def is_frequent_word(int_word, t=1e-5):
    p =  1 - np.sqrt(t / word_frequency(int_word))
    if p > random.random():
        return True
    else:
        return False

train_words = [int_w for int_w in int_words if not is_frequent_word(int_w)]# The final subsampled word list

# %%
len(int_words), len(train_words)
# Out:
# (16680599, 4625449)

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    end = idx + R
    target_words = set(words[start:end+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, shape=(None), name='inputs')
    labels = tf.placeholder(tf.int32, shape=(None, None), name='inputs')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %%
inputs.shape
# Out:
# TensorShape(None)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 6.1607 0.4307 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 6.8418 0.4000 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 7.8794 0.4161 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 9.2696 0.4517 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 10.1449 0.3984 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 10.8769 0.3721 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 11.3820 0.4099 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 12.0406 0.4186 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 12.3613 0.3805 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 12.7661 0.3730 sec/batch
# Nearest to s: frontline, janusz, yak, ebooks, smashed, singleton, pelicans, toile,
# Nearest to while: matos, veneto, prescribing, marketable, thud, mishnaic, jervis, bases,
# Nearest to have: myocardium, coffers, loam, decommissioning, farmington, flutist, vaudeville, roar,
# Nearest to such: rire, devry, subjecting, meteorological, anatolian, proteg, terrible, tout,
# Nearest to one: minsky, bruised, csa, outfielders, submitted, reenactments, hardens, sympathizer,
# Nearest to a: shema, alexa, harper, anic, qualitative, rivas, muselar, emirate,
# Nearest to these: compaq, moth, curriculum, actium, ume, biscay, eritis, athelstan,
# Nearest to during: leroy, hilly, warmblood, perturbed, siro, rabia, cellist, kagoshima,
# Nearest to active: checking, marrakech, charms, abruzzo, nanking, brattle, terri, eros,
# Nearest to test: kibbutz, peano, wenzel, calorimetry, plump, mans, skybox, holies,
# Nearest to discovered: hickok, taciturn, manchuria, unheated, stereotyping, viagra, monumenta, bride,
# Nearest to marriage: undernourished, misread, pokes, mustafa, unsound, chogm, opanal, silico,
# Nearest to writers: blasting, larsson, spoofed, draconis, bureaucrats, virtuosic, freising, topographical,
# Nearest to institute: zahara, mango, repulse, kinetochores, huguenots, abh, lobo, weight,
# Nearest to placed: sponsorships, hampering, terraced, yamaguchi, agnostic, ovale, guebuza, hayman,
# Nearest to mean: pfc, logs, bangkok, remodeled, continuities, vitriolic, bryant, masts,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 12.7808 0.4159 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 13.2544 0.4275 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 13.3639 0.3835 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 13.9978 0.4296 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 14.4672 0.4060 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 13.5462 0.3769 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 13.7478 0.4023 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 14.2813 0.4390 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 14.0810 0.4686 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 13.9156 0.3935 sec/batch
# Nearest to s: ebooks, frontline, smashed, signage, neurotransmitter, janusz, yak, cham,
# Nearest to while: matos, prescribing, extremophiles, tallahassee, jervis, ousia, thud, veneto,
# Nearest to have: coffers, roar, myocardium, illustrious, forensics, draft, captioned, interleave,
# Nearest to such: rire, subjecting, bulbous, devry, sportscaster, lordships, bellini, tina,
# Nearest to one: minsky, laurent, submitted, developers, bsp, csa, reproducing, vine,
# Nearest to a: shema, physically, sparsely, harper, mistaken, index, rivas, qualitative,
# Nearest to these: moth, compaq, curriculum, ume, biscay, lehi, kotoku, mediumwave,
# Nearest to during: hilly, leroy, siro, warmblood, cellist, rabia, perturbed, tunics,
# Nearest to active: marrakech, checking, charms, abruzzo, nanking, ivies, cephalon, fetching,
# Nearest to test: kibbutz, peano, wenzel, skybox, holies, radiochemical, calorimetry, plump,
# Nearest to discovered: manchuria, hickok, stereotyping, bilabial, taciturn, viagra, unheated, partials,
# Nearest to marriage: undernourished, misread, silico, unsound, mustafa, chogm, pokes, ule,
# Nearest to writers: draconis, topographical, spoofed, blasting, larsson, freising, supercluster, bureaucrats,
# Nearest to institute: zahara, repulse, abh, mango, kinetochores, lobo, syzygy, huguenots,
# Nearest to placed: sponsorships, hampering, terraced, ovale, yamaguchi, outstretched, guebuza, agnostic,
# Nearest to mean: pfc, vitriolic, bangkok, cukor, sorenson, masts, nisibis, nubia,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 13.9020 0.3704 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 14.0008 0.4047 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 13.8701 0.3743 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 13.8516 0.3527 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 14.0990 0.3646 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 13.6400 0.3611 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 13.6745 0.3726 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 13.9554 0.3718 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 13.6364 0.3687 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 13.2894 0.3688 sec/batch
# Nearest to s: ebooks, smashed, frontline, signage, water, neurotransmitter, tornado, features,
# Nearest to while: learn, update, matos, founded, extremophiles, prescribing, ousia, bases,
# Nearest to have: draft, illustrious, roar, coffers, here, forensics, tip, houses,
# Nearest to such: rire, subjecting, sportscaster, bulbous, bellini, flame, lordships, division,
# Nearest to one: minsky, developers, laurent, submitted, includes, reproducing, women, vine,
# Nearest to a: physically, harper, sparsely, index, mistaken, shema, submachine, qualitative,
# Nearest to these: moth, curriculum, compaq, place, classico, supremacy, ume, lump,
# Nearest to during: hilly, leroy, kjell, sterile, pantheon, graceful, refinements, tunics,
# Nearest to active: marrakech, checking, charms, ivies, nanking, scoreboard, terri, schnitzler,
# Nearest to test: kibbutz, peano, skybox, holies, coerce, calorimetry, qana, cerca,
# Nearest to discovered: manchuria, bilabial, taciturn, monumenta, stereotyping, hickok, isomer, viagra,
# Nearest to marriage: undernourished, silico, chogm, imhotep, ule, misread, unsound, mustafa,
# Nearest to writers: topographical, draconis, grosvenor, supercluster, officeholders, niigata, freising, larsson,
# Nearest to institute: zahara, repulse, abh, kinetochores, syzygy, mango, kissinger, huguenots,
# Nearest to placed: sponsorships, terraced, hampering, ovale, patricio, freethinkers, outstretched, mellaart,
# Nearest to mean: vitriolic, pfc, bangkok, taganrog, nisibis, sorenson, cukor, rup,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 13.2727 0.3766 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 13.1367 0.3688 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 12.9192 0.3645 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 12.5653 0.3656 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 13.0088 0.3771 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 13.2657 0.3634 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 12.5292 0.3668 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 12.8322 0.3639 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 12.3375 0.3696 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 12.1782 0.3648 sec/batch
# Nearest to s: ebooks, smashed, frontline, signage, tornado, neurotransmitter, eventual, features,
# Nearest to while: learn, update, founded, matos, bases, heavens, prescribing, ousia,
# Nearest to have: draft, illustrious, tip, roar, here, forensics, coffers, houses,
# Nearest to such: sportscaster, rire, subjecting, division, lordships, flame, bellini, bulbous,
# Nearest to one: minsky, developers, submitted, laurent, reproducing, contention, women, bsp,
# Nearest to a: physically, harper, sparsely, index, shema, mistaken, ganz, qualitative,
# Nearest to these: moth, curriculum, place, compaq, supremacy, classico, loyal, lump,
# Nearest to during: hilly, percent, sterile, pantheon, fiction, lev, kjell, horn,
# Nearest to active: marrakech, checking, ivies, charms, nanking, scoreboard, schnitzler, suffers,
# Nearest to test: kibbutz, peano, coerce, skybox, holies, cerca, calorimetry, qana,
# Nearest to discovered: manchuria, bilabial, isomer, bride, monumenta, bahraini, taciturn, stereotyping,
# Nearest to marriage: undernourished, silico, lilia, mustafa, banzer, imhotep, chogm, saunderson,
# Nearest to writers: topographical, draconis, grosvenor, effectors, rau, supercluster, niigata, officeholders,
# Nearest to institute: repulse, zahara, syzygy, kissinger, abh, kinetochores, uncircumcised, huguenots,
# Nearest to placed: sponsorships, terraced, patricio, freethinkers, hampering, supermarket, ovale, outstretched,
# Nearest to mean: vitriolic, rup, sorenson, nisibis, taganrog, bangkok, cukor, escapees,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 12.5636 0.3692 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 11.6639 13.6153 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 11.6570 0.4387 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 11.5498 0.4169 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 11.8337 0.3760 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 11.7744 0.4147 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 11.9174 0.3088 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 11.5587 0.4228 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 11.9192 0.3684 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 11.1296 0.3733 sec/batch
# Nearest to s: ebooks, frontline, tornado, smashed, neurotransmitter, signage, eventual, buy,
# Nearest to while: learn, update, founded, bases, scenario, heavens, matos, prescribing,
# Nearest to have: draft, illustrious, tip, forensics, roar, coffers, vaudeville, homeland,
# Nearest to such: division, sportscaster, subjecting, rire, lordships, bellini, flame, bulbous,
# Nearest to one: minsky, developers, reproducing, submitted, laurent, contention, magnets, bsp,
# Nearest to a: physically, sparsely, harper, index, shema, mistaken, ganz, submachine,
# Nearest to these: moth, curriculum, place, compaq, supremacy, loyal, classico, organizing,
# Nearest to during: hilly, sterile, pantheon, horn, percent, kjell, lev, fiction,
# Nearest to active: checking, marrakech, suffers, ivies, charms, scoreboard, nanking, schnitzler,
# Nearest to test: kibbutz, coerce, peano, api, holies, cerca, skybox, qana,
# Nearest to discovered: manchuria, bride, bilabial, isomer, reynolds, shedding, yuan, noticeable,
# Nearest to marriage: undernourished, spelling, conversions, mustafa, fundraising, hal, lilia, pinnacle,
# Nearest to writers: topographical, grosvenor, saint, draconis, effectors, rau, sufferer, niigata,
# Nearest to institute: repulse, kissinger, syzygy, darkly, uncircumcised, zahara, huguenots, abh,
# Nearest to placed: patricio, supermarket, rituals, freethinkers, view, terraced, sponsorships, ceylon,
# Nearest to mean: vitriolic, rup, sack, sorenson, taganrog, nisibis, bangkok, overworld,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 11.3992 0.3759 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 11.2813 0.3747 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 10.8443 0.3786 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 10.8742 0.3735 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 10.4880 0.3704 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 10.5278 0.3766 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 9.9679 0.3686 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 10.0673 0.3695 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 9.8985 0.3732 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 10.0617 0.3775 sec/batch
# Nearest to s: ebooks, frontline, tornado, neurotransmitter, fluid, smashed, buy, signage,
# Nearest to while: update, learn, bases, founded, scenario, heavens, matos, prescribing,
# Nearest to have: draft, tip, illustrious, forensics, roar, vaudeville, stupid, evening,
# Nearest to such: subjecting, sportscaster, rire, lordships, division, bulbous, bellini, vhs,
# Nearest to one: minsky, developers, reproducing, laurent, bsp, magnets, contention, submitted,
# Nearest to a: sparsely, physically, harper, shema, submachine, qualitative, ganz, index,
# Nearest to these: curriculum, moth, place, compaq, loyal, supremacy, assurance, lump,
# Nearest to during: hilly, sterile, pantheon, horn, excavated, kjell, lev, weakly,
# Nearest to active: checking, suffers, online, marrakech, farmer, ivies, relevant, charms,
# Nearest to test: kibbutz, api, coerce, peano, appropriations, accompli, qana, holies,
# Nearest to discovered: bride, manchuria, bilabial, reynolds, yuan, isomer, noticeable, shedding,
# Nearest to marriage: spelling, evidence, conversions, undernourished, standardized, fundraising, imagined, dimensional,
# Nearest to writers: saint, topographical, implications, lang, reliability, fluctuating, grosvenor, reflecting,
# Nearest to institute: physiology, repulse, darkly, kissinger, uncircumcised, syzygy, procurement, scrolls,
# Nearest to placed: patricio, rituals, view, supermarket, ceylon, freethinkers, reader, terraced,
# Nearest to mean: sack, vitriolic, rup, sorenson, bangkok, taganrog, hassel, nisibis,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 10.0995 0.3809 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 9.6867 0.3710 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 9.6447 0.3756 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 9.6080 0.3818 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 9.7094 0.3744 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 9.5671 0.3792 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 9.1101 0.3845 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 9.1904 0.3470 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 9.4756 0.3729 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 8.7795 0.3745 sec/batch
# Nearest to s: frontline, ebooks, fluid, neurotransmitter, tornado, ratified, water, ep,
# Nearest to while: update, bases, learn, heavens, prescribing, matos, founded, scenario,
# Nearest to have: draft, illustrious, tip, roar, forensics, captioned, in, stupid,
# Nearest to such: subjecting, sportscaster, lordships, division, bellini, rire, bulbous, condoleezza,
# Nearest to one: of, minsky, developers, as, reproducing, bsp, illustration, contention,
# Nearest to a: way, sparsely, physically, harper, to, five, that, debate,
# Nearest to these: curriculum, moth, place, compaq, of, loyal, for, supremacy,
# Nearest to during: hilly, sterile, horn, pantheon, excavated, kjell, weakly, lev,
# Nearest to active: checking, suffers, marrakech, farmer, online, ching, charms, ivies,
# Nearest to test: kibbutz, api, coerce, notably, docking, appropriations, peano, accompli,
# Nearest to discovered: bride, manchuria, yuan, bilabial, reynolds, noticeable, isomer, shedding,
# Nearest to marriage: spelling, evidence, conversions, their, standardized, imagined, dimensional, contracted,
# Nearest to writers: saint, topographical, implications, reliability, lang, grosvenor, fluctuating, reflecting,
# Nearest to institute: physiology, repulse, darkly, kissinger, procurement, abolish, scrolls, uncircumcised,
# Nearest to placed: patricio, supermarket, ceylon, rituals, view, freethinkers, reader, terraced,
# Nearest to mean: sack, rup, vitriolic, doomed, sorenson, liberals, brethren, alleging,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 9.2521 0.3854 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 8.6572 0.3744 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 8.3730 0.3732 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 8.8234 0.3659 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 8.7490 0.3680 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 8.6175 0.3702 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 8.4849 0.3735 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 8.4605 0.4190 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 8.0271 0.4000 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 7.8965 0.3676 sec/batch
# Nearest to s: frontline, ebooks, water, treaty, ratified, fluid, on, begin,
# Nearest to while: update, bases, heavens, prescribing, founded, ousia, matos, learn,
# Nearest to have: draft, in, some, illustrious, roar, forensics, kilgore, captioned,
# Nearest to such: subjecting, english, lordships, bulbous, whose, division, bellini, condoleezza,
# Nearest to one: of, three, nine, as, eight, it, all, six,
# Nearest to a: that, to, way, five, but, physically, sparsely, eventually,
# Nearest to these: curriculum, place, moth, of, for, compaq, loyal, least,
# Nearest to during: hilly, sterile, kjell, excavated, pantheon, weakly, horn, iom,
# Nearest to active: suffers, checking, marrakech, online, farmer, ching, charms, moreover,
# Nearest to test: kibbutz, api, notably, coerce, appropriations, docking, odds, flat,
# Nearest to discovered: bride, manchuria, reynolds, yuan, bilabial, isomer, noticeable, observance,
# Nearest to marriage: spelling, evidence, their, conversions, imagined, standardized, dimensional, contracted,
# Nearest to writers: saint, topographical, reliability, fluctuating, implications, grosvenor, lang, reflecting,
# Nearest to institute: physiology, repulse, kissinger, darkly, procurement, abolish, scrolls, uncircumcised,
# Nearest to placed: patricio, ceylon, view, supermarket, freethinkers, rituals, reader, accrue,
# Nearest to mean: sack, vitriolic, rup, doomed, liberals, brethren, desktops, bangkok,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 7.9170 0.3739 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 8.2783 0.3738 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 7.8732 0.3671 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 8.2467 0.3633 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 8.1438 0.3696 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 7.7738 0.3657 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 8.1825 0.3614 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 7.8394 0.3678 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 7.6529 0.3719 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 7.5028 0.3676 sec/batch
# Nearest to s: on, frontline, ebooks, water, declared, treaty, begin, and,
# Nearest to while: update, founded, bases, learn, heavens, scenario, prescribing, relieved,
# Nearest to have: in, draft, some, same, or, the, evening, illustrious,
# Nearest to such: subjecting, english, whose, to, for, division, lordships, condoleezza,
# Nearest to one: nine, three, eight, six, four, of, it, all,
# Nearest to a: that, way, to, but, eventually, five, physically, usually,
# Nearest to these: of, place, for, curriculum, moth, least, the, i,
# Nearest to during: hilly, sterile, percent, kjell, excavated, emergency, weakly, coals,
# Nearest to active: checking, suffers, marrakech, online, farmer, relevant, ching, moreover,
# Nearest to test: kibbutz, api, notably, appropriations, coerce, docking, puns, accompli,
# Nearest to discovered: manchuria, bride, yuan, reynolds, bilabial, observance, noticeable, isomer,
# Nearest to marriage: evidence, spelling, their, conversions, jerome, mustafa, undernourished, dimensional,
# Nearest to writers: saint, topographical, grosvenor, fluctuating, reliability, implications, reflecting, lang,
# Nearest to institute: physiology, repulse, procurement, abolish, kissinger, darkly, scrolls, huguenots,
# Nearest to placed: patricio, reader, ceylon, view, supermarket, freethinkers, accrue, terraced,
# Nearest to mean: sack, vitriolic, rup, doomed, liberals, brethren, desktops, hassel,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 7.6912 0.3728 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 7.8302 0.3642 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 7.5801 0.1825 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 7.4240 0.3651 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 7.7070 0.3653 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 7.4728 0.3748 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 7.4910 30.0572 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 7.4280 0.4433 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 7.4278 32.3798 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 7.1094 32.3871 sec/batch
# Nearest to s: on, water, declared, begin, treaty, frontline, slightly, buy,
# Nearest to while: founded, update, learn, bases, not, scenario, heavens, name,
# Nearest to have: draft, in, some, same, or, evening, here, the,
# Nearest to such: whose, english, subjecting, to, division, for, lordships, vivid,
# Nearest to one: nine, three, eight, six, four, rate, zero, it,
# Nearest to a: way, that, usually, eventually, but, to, physically, based,
# Nearest to these: place, of, for, curriculum, least, moth, last, the,
# Nearest to during: hilly, percent, sterile, emergency, per, kjell, excavated, coals,
# Nearest to active: suffers, checking, marrakech, online, moreover, relevant, farmer, practical,
# Nearest to test: kibbutz, api, notably, flat, appropriations, puns, docking, holies,
# Nearest to discovered: manchuria, yuan, bride, reynolds, observance, bilabial, exercise, noticeable,
# Nearest to marriage: evidence, their, spelling, conversions, jerome, mustafa, imagined, resource,
# Nearest to writers: saint, topographical, reflecting, reliability, grosvenor, fluctuating, implications, leonard,
# Nearest to institute: physiology, repulse, abolish, procurement, jointly, darkly, kissinger, arrests,
# Nearest to placed: reader, patricio, ceylon, view, freethinkers, launched, terraced, supermarket,
# Nearest to mean: sack, vitriolic, rup, doomed, liberals, desktops, brethren, nubia,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 7.0484 32.3985 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 7.3038 32.2957 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 6.9622 0.4475 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 6.8480 2.9765 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 6.7203 32.3064 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 6.6078 0.4410 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 7.0782 32.3679 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 6.8238 31.5847 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 6.5849 0.4196 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 6.8644 0.4021 sec/batch
# Nearest to s: water, begin, declared, buy, frontline, treaty, slightly, features,
# Nearest to while: founded, learn, update, bases, not, scenario, heavens, prescribing,
# Nearest to have: draft, some, in, same, height, houses, here, tip,
# Nearest to such: subjecting, english, whose, division, to, for, lordships, criticism,
# Nearest to one: nine, three, eight, six, four, rate, zero, submitted,
# Nearest to a: way, usually, that, eventually, physically, index, sparsely, but,
# Nearest to these: place, for, of, curriculum, least, moth, last, loyal,
# Nearest to during: hilly, percent, emergency, sterile, emphasis, per, moderate, forced,
# Nearest to active: checking, suffers, relevant, marrakech, online, farmer, moreover, using,
# Nearest to test: kibbutz, api, notably, flat, appropriations, holies, puns, saviour,
# Nearest to discovered: manchuria, yuan, bride, reynolds, observance, exercise, noticeable, bilabial,
# Nearest to marriage: evidence, their, spelling, imagined, conversions, standardized, jerome, resource,
# Nearest to writers: saint, topographical, reliability, reflecting, implications, grosvenor, leonard, fluctuating,
# Nearest to institute: physiology, repulse, abolish, jointly, procurement, communist, escaped, statistical,
# Nearest to placed: reader, patricio, view, ceylon, freethinkers, launched, terraced, supermarket,
# Nearest to mean: sack, vitriolic, rup, liberals, doomed, prestige, desktops, brethren,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 6.8450 0.4006 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 6.7306 0.3991 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 6.3936 0.3969 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 6.4729 0.4096 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 6.6849 0.4150 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 6.4076 0.4103 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 6.3317 0.4117 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 6.5722 0.4055 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 6.0945 0.3980 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 6.3915 0.3930 sec/batch
# Nearest to s: begin, buy, frontline, declared, features, water, ebooks, treaty,
# Nearest to while: learn, founded, update, bases, scenario, prescribing, heavens, eachother,
# Nearest to have: draft, some, tip, in, houses, height, captioned, speed,
# Nearest to such: subjecting, english, whose, division, to, numerical, criticism, for,
# Nearest to one: nine, eight, three, six, four, seven, footballer, minsky,
# Nearest to a: way, usually, eventually, physically, positive, delay, readers, index,
# Nearest to these: place, curriculum, for, least, moth, of, loyal, dated,
# Nearest to during: hilly, percent, emergency, dies, fiction, forced, sterile, per,
# Nearest to active: checking, suffers, relevant, marrakech, farmer, moreover, online, attempts,
# Nearest to test: kibbutz, notably, api, flat, appropriations, holies, puns, cortez,
# Nearest to discovered: manchuria, yuan, bride, reynolds, observance, exercise, noticeable, bilabial,
# Nearest to marriage: evidence, their, spelling, imagined, standardized, conversions, money, explain,
# Nearest to writers: saint, topographical, reliability, grosvenor, reflecting, implications, leonard, disassembled,
# Nearest to institute: physiology, repulse, jointly, procurement, abolish, escaped, sitting, statistical,
# Nearest to placed: reader, view, ceylon, patricio, freethinkers, launched, rituals, terraced,
# Nearest to mean: sack, vitriolic, rup, liberals, doomed, prestige, desktops, brethren,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 6.4284 0.4092 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 6.0556 0.3700 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 6.1466 0.3793 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 6.2473 0.3912 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 6.0583 0.4081 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 5.9184 0.3910 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 5.9527 0.3816 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 6.3041 0.4085 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 5.9709 0.4619 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 6.1297 0.4116 sec/batch
# Nearest to s: frontline, buy, ebooks, begin, features, declared, treaty, limit,
# Nearest to while: learn, update, founded, bases, heavens, scenario, prescribing, arrest,
# Nearest to have: draft, some, tip, height, houses, forensics, speed, dangers,
# Nearest to such: subjecting, whose, division, english, numerical, lordships, flame, options,
# Nearest to one: nine, eight, six, three, four, footballer, seven, b,
# Nearest to a: way, delay, usually, principally, physically, positive, index, harper,
# Nearest to these: curriculum, place, moth, least, dated, loyal, for, complicated,
# Nearest to during: hilly, percent, emergency, dies, horn, iom, fiction, everywhere,
# Nearest to active: checking, relevant, suffers, farmer, attempts, moreover, marrakech, online,
# Nearest to test: notably, kibbutz, api, flat, appropriations, holies, puns, treat,
# Nearest to discovered: manchuria, bride, yuan, reynolds, exercise, observance, noticeable, january,
# Nearest to marriage: evidence, spelling, their, standardized, imagined, conversions, money, explain,
# Nearest to writers: saint, topographical, reliability, reflecting, implications, leonard, grosvenor, fluctuating,
# Nearest to institute: repulse, jointly, physiology, abolish, escaped, procurement, communist, scrolls,
# Nearest to placed: reader, view, ceylon, patricio, launched, freethinkers, rituals, terraced,
# Nearest to mean: sack, vitriolic, liberals, doomed, prestige, rup, resulted, brethren,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 6.4326 0.3854 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 5.7235 0.3848 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 6.3149 0.4364 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 5.9384 0.4029 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 5.8778 0.4189 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 5.8403 0.3909 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 5.8083 0.3947 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 5.8586 0.3784 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 5.8828 0.0927 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 5.9251 0.3738 sec/batch
# Nearest to s: frontline, buy, begin, ebooks, declared, treaty, features, newspaper,
# Nearest to while: learn, update, founded, heavens, bases, prescribing, scenario, arrest,
# Nearest to have: draft, some, height, tip, captioned, forensics, kilgore, roar,
# Nearest to such: subjecting, lordships, numerical, whose, cassidy, flame, bulbous, sounding,
# Nearest to one: nine, eight, six, three, four, footballer, seven, b,
# Nearest to a: principally, delay, way, positive, usually, physically, index, mistaken,
# Nearest to these: curriculum, moth, place, dated, compaq, complicated, loyal, least,
# Nearest to during: hilly, percent, emergency, horn, everywhere, dies, iom, forced,
# Nearest to active: checking, suffers, relevant, marrakech, farmer, attempts, moreover, online,
# Nearest to test: notably, kibbutz, flat, api, appropriations, puns, deliberately, treat,
# Nearest to discovered: manchuria, bride, yuan, reynolds, exercise, observance, noticeable, solar,
# Nearest to marriage: spelling, evidence, their, imagined, standardized, undernourished, mustafa, money,
# Nearest to writers: saint, topographical, reliability, reflecting, grosvenor, leonard, implications, disassembled,
# Nearest to institute: repulse, jointly, physiology, procurement, abolish, discouraged, escaped, kissinger,
# Nearest to placed: reader, patricio, view, ceylon, freethinkers, terraced, launched, supermarket,
# Nearest to mean: sack, vitriolic, rup, prestige, liberals, doomed, resulted, sheet,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 5.8355 0.3801 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 6.0381 0.3789 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 5.8299 0.3732 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 6.0041 0.3350 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 5.6703 0.3750 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 5.6749 0.3748 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 5.5644 0.3720 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 5.7157 0.3974 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 5.6660 0.3810 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 5.4364 0.3829 sec/batch
# Nearest to s: frontline, begin, ebooks, buy, newspaper, cham, eventual, schism,
# Nearest to while: learn, heavens, update, founded, prescribing, relieved, bases, eachother,
# Nearest to have: draft, height, some, tip, captioned, forensics, illustrious, regionally,
# Nearest to such: subjecting, numerical, flame, lordships, cassidy, whose, options, sounding,
# Nearest to one: nine, eight, six, footballer, three, four, seven, b,
# Nearest to a: principally, delay, positive, way, physically, sparsely, harper, usually,
# Nearest to these: moth, curriculum, complicated, place, dated, compaq, lump, organizing,
# Nearest to during: hilly, horn, percent, everywhere, iom, emergency, anjouan, dies,
# Nearest to active: checking, relevant, suffers, marrakech, farmer, attempts, thant, ching,
# Nearest to test: kibbutz, notably, flat, api, appropriations, holies, puns, qana,
# Nearest to discovered: manchuria, bride, yuan, reynolds, exercise, observance, noticeable, solar,
# Nearest to marriage: imagined, their, spelling, standardized, evidence, jerome, mustafa, conversions,
# Nearest to writers: saint, topographical, grosvenor, reliability, leonard, reflecting, implications, sufferer,
# Nearest to institute: repulse, jointly, discouraged, physiology, procurement, scrolls, abolish, escaped,
# Nearest to placed: reader, patricio, view, ceylon, freethinkers, terraced, supermarket, rituals,
# Nearest to mean: sack, vitriolic, liberals, prestige, doomed, rup, sheet, expect,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 5.4347 0.3819 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 5.4480 0.3709 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 5.6755 0.3855 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 5.6002 0.3956 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 5.4206 0.4155 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 5.5110 0.4681 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 5.6001 0.3775 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 5.7282 0.3971 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 5.2767 0.4006 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 5.3568 0.4096 sec/batch
# Nearest to s: frontline, ebooks, begin, cham, newspaper, cnidaria, buy, eventual,
# Nearest to while: learn, heavens, update, prescribing, relieved, matos, arrest, yugoslavian,
# Nearest to have: draft, height, captioned, some, tip, forensics, kilgore, roar,
# Nearest to such: subjecting, flame, numerical, lordships, sounding, options, cassidy, shifting,
# Nearest to one: nine, eight, six, footballer, four, three, seven, b,
# Nearest to a: principally, positive, delay, index, sided, usually, way, physically,
# Nearest to these: moth, curriculum, complicated, compaq, lump, initials, mediumwave, celibate,
# Nearest to during: hilly, horn, iom, anjouan, percent, emergency, everywhere, dies,
# Nearest to active: checking, relevant, suffers, marrakech, farmer, thant, ivies, charms,
# Nearest to test: kibbutz, api, flat, notably, appropriations, holies, puns, washers,
# Nearest to discovered: bride, manchuria, reynolds, yuan, solar, exercise, noticeable, observance,
# Nearest to marriage: imagined, their, spelling, standardized, evidence, jerome, conversions, undernourished,
# Nearest to writers: saint, topographical, grosvenor, reliability, leonard, implications, disassembled, reflecting,
# Nearest to institute: repulse, jointly, physiology, discouraged, scrolls, procurement, arrests, abolish,
# Nearest to placed: freethinkers, patricio, view, reader, supermarket, ceylon, terraced, rituals,
# Nearest to mean: sack, vitriolic, liberals, sheet, doomed, prestige, genetic, cognitive,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 5.3933 0.3838 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 5.4559 0.3804 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 5.3411 0.3845 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 5.4758 0.3748 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 5.2528 0.3721 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 5.2700 0.3710 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 5.4236 0.3683 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 5.2089 0.3899 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 5.1902 0.3677 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 5.3669 0.3890 sec/batch
# Nearest to s: frontline, ebooks, newspaper, begin, cham, cnidaria, schism, television,
# Nearest to while: learn, yugoslavian, prescribing, heavens, update, relieved, matos, arrest,
# Nearest to have: draft, some, height, regionally, tip, captioned, forensics, blatant,
# Nearest to such: subjecting, flame, sounding, numerical, lordships, options, cassidy, criticism,
# Nearest to one: nine, eight, six, footballer, four, seven, three, b,
# Nearest to a: principally, positive, delay, confidential, index, sparsely, harper, sided,
# Nearest to these: moth, curriculum, complicated, lump, initials, dated, apollo, compaq,
# Nearest to during: hilly, horn, iom, emergency, dies, anjouan, percent, pantheon,
# Nearest to active: checking, relevant, suffers, farmer, marrakech, thant, charms, terri,
# Nearest to test: kibbutz, notably, api, flat, holies, appropriations, odds, puns,
# Nearest to discovered: manchuria, bride, reynolds, yuan, solar, isomer, consubstantiation, noticeable,
# Nearest to marriage: imagined, spelling, their, standardized, evidence, jerome, conversions, fundraising,
# Nearest to writers: saint, topographical, grosvenor, leonard, science, reliability, implications, observational,
# Nearest to institute: repulse, physiology, jointly, discouraged, kissinger, scrolls, procurement, pluriform,
# Nearest to placed: freethinkers, patricio, view, supermarket, terraced, ceylon, reader, rituals,
# Nearest to mean: sack, vitriolic, genetic, liberals, expect, doomed, prestige, sheet,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 5.3347 0.3835 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 5.0364 0.3750 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 5.1752 0.3781 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 5.3131 0.3836 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 5.0356 0.3708 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 5.1990 0.3705 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 5.6996 0.3747 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 5.1276 0.3716 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 5.3980 0.3858 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 5.3660 0.3721 sec/batch
# Nearest to s: frontline, newspaper, ebooks, television, cnidaria, cham, begin, schism,
# Nearest to while: yugoslavian, matos, ousia, prescribing, relieved, eachother, learn, heavens,
# Nearest to have: draft, height, regionally, some, tip, captioned, illustrious, blatant,
# Nearest to such: subjecting, flame, sounding, numerical, lordships, options, shifting, explain,
# Nearest to one: nine, eight, six, footballer, four, b, seven, three,
# Nearest to a: principally, confidential, monophosphate, positive, delay, sustain, mistaken, peculiarity,
# Nearest to these: moth, curriculum, initials, lump, complicated, dated, organizing, least,
# Nearest to during: hilly, horn, iom, dies, emergency, percent, lev, anjouan,
# Nearest to active: checking, relevant, suffers, farmer, thant, marrakech, attempts, charms,
# Nearest to test: kibbutz, notably, flat, api, odds, puns, holies, appropriations,
# Nearest to discovered: manchuria, bride, reynolds, solar, isomer, viagra, consubstantiation, monumenta,
# Nearest to marriage: imagined, spelling, rector, jerome, their, fundraising, mustafa, breakers,
# Nearest to writers: saint, topographical, leonard, science, grosvenor, lang, implications, observational,
# Nearest to institute: repulse, jointly, physiology, pluriform, kissinger, capitol, discouraged, huguenots,
# Nearest to placed: freethinkers, patricio, supermarket, terraced, view, ceylon, reader, draftsman,
# Nearest to mean: vitriolic, sack, genetic, liberals, expect, sheet, cognitive, rup,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 5.1198 0.3804 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 5.1145 0.3700 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 5.1004 0.3711 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 5.1892 0.3868 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 5.2860 0.3754 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 5.2651 0.3690 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 5.0334 0.3704 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 5.3849 0.4042 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 5.0646 0.3872 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 5.2656 0.3769 sec/batch
# Nearest to s: frontline, newspaper, cham, ebooks, cnidaria, begin, television, smashed,
# Nearest to while: yugoslavian, relieved, heavens, matos, ousia, skyline, prescribing, learn,
# Nearest to have: draft, captioned, regionally, some, height, blatant, roar, coffers,
# Nearest to such: subjecting, flame, sounding, numerical, lordships, polyglot, shifting, options,
# Nearest to one: footballer, eight, nine, six, b, four, seven, athlete,
# Nearest to a: confidential, principally, positive, monophosphate, sustain, mistaken, try, jose,
# Nearest to these: moth, lump, apollo, curriculum, initials, complicated, dated, crone,
# Nearest to during: hilly, horn, iom, dynasties, percent, anjouan, dies, emergency,
# Nearest to active: checking, relevant, suffers, farmer, thant, marrakech, terri, attempts,
# Nearest to test: kibbutz, notably, flat, api, odds, puns, appropriations, holies,
# Nearest to discovered: bride, manchuria, reynolds, solar, isomer, noticeable, viagra, monumenta,
# Nearest to marriage: imagined, spelling, their, rector, jerome, heir, evidence, breakers,
# Nearest to writers: saint, topographical, leonard, science, grosvenor, lang, implications, revolted,
# Nearest to institute: repulse, jointly, physiology, pluriform, discouraged, capitol, huguenots, biggest,
# Nearest to placed: freethinkers, patricio, terraced, ceylon, supermarket, view, draftsman, milder,
# Nearest to mean: vitriolic, sack, genetic, liberals, cognitive, expect, pointing, sheet,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 5.1791 0.3727 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 4.9339 0.3726 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 5.0742 0.4395 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 5.0407 0.3997 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 5.0692 0.3642 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.9350 0.3702 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 4.8920 0.3839 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 4.8219 0.4244 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 4.9959 0.4314 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 5.0852 0.5069 sec/batch
# Nearest to s: frontline, cnidaria, newspaper, cham, ebooks, begin, smashed, bebop,
# Nearest to while: yugoslavian, relieved, skyline, matos, heavens, ousia, eachother, brevity,
# Nearest to have: regionally, draft, captioned, height, blatant, some, illustrious, tip,
# Nearest to such: subjecting, sounding, flame, lordships, polyglot, numerical, refugee, boldness,
# Nearest to one: six, eight, footballer, four, nine, minsky, athlete, b,
# Nearest to a: confidential, principally, positive, try, monophosphate, controller, peculiarity, rotunda,
# Nearest to these: moth, initials, curriculum, lump, apollo, complicated, dated, least,
# Nearest to during: hilly, horn, iom, anjouan, dynasties, emergency, benenson, percent,
# Nearest to active: checking, farmer, relevant, suffers, thant, terri, target, marrakech,
# Nearest to test: kibbutz, notably, flat, api, odds, puns, appropriations, holies,
# Nearest to discovered: bride, reynolds, manchuria, solar, noticeable, isomer, viagra, producing,
# Nearest to marriage: imagined, their, spelling, undernourished, jerome, rector, heir, breakers,
# Nearest to writers: saint, leonard, topographical, science, grosvenor, observational, lang, revolted,
# Nearest to institute: physiology, jointly, capitol, pluriform, repulse, technology, discouraged, biggest,
# Nearest to placed: freethinkers, patricio, terraced, supermarket, ceylon, draftsman, view, milder,
# Nearest to mean: vitriolic, sack, cognitive, liberals, genetic, antithesis, sheet, pointing,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.8623 0.4936 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.9606 0.4916 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 4.9661 0.4803 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 5.1564 0.4785 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.8686 0.4233 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 4.7924 0.3734 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.8900 0.4138 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.9904 0.3724 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.7530 0.3684 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.9689 0.3543 sec/batch
# Nearest to s: frontline, newspaper, cnidaria, smashed, ebooks, cham, television, begin,
# Nearest to while: yugoslavian, skyline, relieved, ousia, illuminated, brevity, matos, arrest,
# Nearest to have: regionally, draft, captioned, blatant, height, some, illustrious, supplanted,
# Nearest to such: subjecting, flame, sounding, lordships, polyglot, numerical, boldness, augmented,
# Nearest to one: six, eight, footballer, four, nine, athlete, b, minsky,
# Nearest to a: positive, confidential, try, sided, controller, rotunda, principally, monophosphate,
# Nearest to these: moth, lump, initials, apollo, curriculum, dated, diametrically, complicated,
# Nearest to during: hilly, horn, iom, dynasties, anjouan, dies, emergency, percent,
# Nearest to active: checking, farmer, thant, relevant, terri, suffers, marrakech, target,
# Nearest to test: kibbutz, odds, notably, flat, api, holies, puns, qana,
# Nearest to discovered: reynolds, bride, solar, manchuria, noticeable, isomer, absorbing, producing,
# Nearest to marriage: imagined, their, spelling, jerome, heir, undernourished, rector, hal,
# Nearest to writers: science, saint, leonard, topographical, grosvenor, lang, observational, hesitated,
# Nearest to institute: physiology, jointly, repulse, capitol, pluriform, technology, discouraged, humanities,
# Nearest to placed: freethinkers, terraced, patricio, supermarket, draftsman, ceylon, vitriolic, sponsorships,
# Nearest to mean: vitriolic, sack, antithesis, cognitive, liberals, amalfi, genetic, taoism,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.6865 0.3768 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 4.8184 0.3670 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 4.8367 0.3680 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.8186 0.3826 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.7590 0.4082 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.8847 0.3642 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 4.8688 0.3852 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 4.6584 0.3957 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 4.8299 0.3937 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.6019 0.4147 sec/batch
# Nearest to s: frontline, cnidaria, newspaper, smashed, cham, ebooks, leiden, ppen,
# Nearest to while: yugoslavian, ousia, relieved, arrest, skyline, eachother, brevity, matos,
# Nearest to have: regionally, draft, captioned, height, some, blatant, supplanted, coffers,
# Nearest to such: sounding, subjecting, flame, polyglot, lordships, boldness, refugee, wynne,
# Nearest to one: six, eight, four, b, nine, footballer, seven, athlete,
# Nearest to a: confidential, positive, rotunda, try, stubs, monophosphate, peculiarity, saracens,
# Nearest to these: moth, initials, lump, apollo, curriculum, dated, diametrically, supremacy,
# Nearest to during: horn, hilly, dynasties, iom, emergency, anjouan, percent, benenson,
# Nearest to active: checking, farmer, terri, thant, relevant, suffers, marrakech, target,
# Nearest to test: kibbutz, odds, puns, qana, notably, api, holies, flat,
# Nearest to discovered: reynolds, solar, bride, manchuria, isomer, noticeable, viagra, absorbing,
# Nearest to marriage: imagined, rector, heir, their, spelling, jerome, hal, undernourished,
# Nearest to writers: science, leonard, saint, topographical, grosvenor, lang, hesitated, births,
# Nearest to institute: jointly, technology, physiology, repulse, pluriform, capitol, humanities, kissinger,
# Nearest to placed: terraced, freethinkers, supermarket, patricio, draftsman, ceylon, vitriolic, wool,
# Nearest to mean: vitriolic, sack, antithesis, cognitive, liberals, prestige, taoism, genetic,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 4.8629 0.3829 sec/batch
# ...
# Nearest to placed: walls, supermarket, vitriolic, surrounded, terraced, draftsman, ceylon, freethinkers,
# Nearest to mean: vitriolic, lon, antithesis, average, underlie, witt, kiwi, liffey,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 4.0432 0.3526 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 4.0262 0.3534 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 4.1516 0.4115 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 4.0274 0.3869 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 4.1437 0.3824 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 4.0178 0.4225 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 4.0688 0.3460 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 4.0308 0.3708 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 4.0875 0.3602 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 4.0462 0.3964 sec/batch
# Nearest to s: perpendicular, smashed, norbert, singleton, frontline, leiden, gunmen, lambeth,
# Nearest to while: yugoslavian, rosicrucians, stacked, overthrowing, skyline, locate, svetlana, transitions,
# Nearest to have: regionally, husband, rescued, been, draft, supplanted, once, ancients,
# Nearest to such: wynne, sounding, subjecting, polyglot, chordal, boldness, anduin, pornographic,
# Nearest to one: llc, minsky, eight, periodic, six, developers, nine, zapata,
# Nearest to a: sided, trivia, terrorists, hospital, saracens, try, archipelagoes, stubs,
# Nearest to these: diametrically, moth, rh, lump, initials, reclassified, feynman, electors,
# Nearest to during: northumberland, dynasties, sheffield, refinements, victory, precludes, disadvantageous, pantheon,
# Nearest to active: terri, relevant, checking, thant, farmer, analogously, functioning, gases,
# Nearest to test: odds, qana, pm, washers, volt, excels, deliberately, ahead,
# Nearest to discovered: solar, reynolds, evidence, scientific, edible, supposed, birch, lovers,
# Nearest to marriage: divorce, legate, disputing, standardized, money, undernourished, fundraising, heir,
# Nearest to writers: science, births, actors, leonard, hugo, fiction, playwrights, autodidacts,
# Nearest to institute: technology, humanities, jointly, physiology, institut, statistical, engineering, management,
# Nearest to placed: walls, supermarket, vitriolic, surrounded, draftsman, ceylon, terraced, freethinkers,
# Nearest to mean: vitriolic, lon, antithesis, average, kiwi, equator, witt, liffey,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 4.0586 0.3849 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 4.0941 0.3723 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.9642 0.4005 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 4.0779 0.3998 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9933 0.4001 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 4.1332 0.3531 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 4.1444 0.3393 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 4.2414 0.3835 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 4.1491 0.3735 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 4.0726 0.3683 sec/batch
# Nearest to s: perpendicular, smashed, norbert, singleton, frontline, lambeth, gunmen, unintentionally,
# Nearest to while: yugoslavian, rosicrucians, overthrowing, stacked, locate, svetlana, transitions, skyline,
# Nearest to have: regionally, husband, been, draft, rescued, supplanted, enmity, ssr,
# Nearest to such: wynne, sounding, subjecting, chordal, boldness, polyglot, anduin, paleocene,
# Nearest to one: six, llc, minsky, eight, periodic, reproducing, rate, four,
# Nearest to a: sided, trivia, terrorists, try, hospital, saracens, archipelagoes, santer,
# Nearest to these: rh, moth, lump, diametrically, initials, reclassified, ke, nutrient,
# Nearest to during: northumberland, sheffield, dynasties, victory, refinements, precludes, disadvantageous, horn,
# Nearest to active: terri, relevant, checking, thant, farmer, functioning, passive, non,
# Nearest to test: odds, qana, deliberately, peano, austrofascism, pm, excels, program,
# Nearest to discovered: reynolds, solar, evidence, scientific, edible, lovers, birch, radiative,
# Nearest to marriage: divorce, legate, disputing, standardized, money, undernourished, fundraising, heir,
# Nearest to writers: science, births, actors, leonard, hugo, fiction, bisexual, playwrights,
# Nearest to institute: technology, humanities, jointly, institut, physiology, management, statistical, discouraged,
# Nearest to placed: supermarket, walls, vitriolic, surrounded, terraced, ceylon, draftsman, freethinkers,
# Nearest to mean: vitriolic, lon, antithesis, witt, kiwi, average, equator, liffey,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 4.0751 0.3771 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 4.0140 0.3812 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 4.0224 0.4403 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.9949 0.4105 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 4.0165 0.3730 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 4.1097 0.3683 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 4.1023 0.3202 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.9941 0.4171 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 4.0776 0.3882 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 4.0214 0.4153 sec/batch
# Nearest to s: perpendicular, smashed, norbert, frontline, singleton, lambeth, unintentionally, gunmen,
# Nearest to while: yugoslavian, rosicrucians, overthrowing, stacked, locate, svetlana, skyline, transitions,
# Nearest to have: regionally, husband, rescued, been, draft, supplanted, once, sha,
# Nearest to such: wynne, subjecting, chordal, boldness, polyglot, sounding, anduin, paleocene,
# Nearest to one: six, eight, minsky, nine, four, llc, mehmed, periodic,
# Nearest to a: sided, trivia, terrorists, hospital, try, saracens, archipelagoes, krajina,
# Nearest to these: diametrically, rh, lump, moth, reclassified, initials, nutrient, electors,
# Nearest to during: northumberland, dynasties, victory, refinements, disadvantageous, precludes, sheffield, pantheon,
# Nearest to active: terri, relevant, checking, thant, passive, farmer, functioning, non,
# Nearest to test: odds, program, qana, docking, deliberately, pm, isotropic, excels,
# Nearest to discovered: solar, reynolds, scientific, evidence, edible, lovers, speculated, radiative,
# Nearest to marriage: divorce, legate, standardized, disputing, money, undernourished, fundraising, heir,
# Nearest to writers: science, births, actors, bisexual, fiction, hugo, playwrights, leonard,
# Nearest to institute: technology, humanities, jointly, statistical, management, discouraged, institut, physiology,
# Nearest to placed: walls, supermarket, vitriolic, surrounded, draftsman, terraced, ceylon, freethinkers,
# Nearest to mean: vitriolic, lon, average, kiwi, antithesis, witt, equator, liffey,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 4.0725 0.3972 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 4.1592 0.3811 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.9407 0.4006 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 4.0546 0.3897 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 4.0105 0.3837 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 4.0570 0.4273 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 4.0316 0.4172 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.9131 0.4207 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.9614 0.4182 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.9296 0.4355 sec/batch
# Nearest to s: perpendicular, frontline, singleton, norbert, smashed, lambeth, gunmen, fluctuations,
# Nearest to while: yugoslavian, rosicrucians, locate, ace, stacked, transitions, svetlana, skyline,
# Nearest to have: regionally, been, rescued, husband, draft, supplanted, ancients, sha,
# Nearest to such: wynne, polyglot, subjecting, boldness, chordal, proteg, sounding, touchstone,
# Nearest to one: periodic, minsky, six, llc, reproducing, eight, estimates, four,
# Nearest to a: sided, trivia, hospital, try, terrorists, archipelagoes, krajina, swap,
# Nearest to these: rh, diametrically, lump, moth, initials, reclassified, nutrient, carve,
# Nearest to during: northumberland, dynasties, precludes, refinements, victory, disadvantageous, sheffield, pantheon,
# Nearest to active: terri, relevant, checking, passive, thant, farmer, non, touchdown,
# Nearest to test: odds, program, qana, isotropic, deliberately, excels, pm, peano,
# Nearest to discovered: solar, reynolds, evidence, edible, scientific, radiative, speculated, lovers,
# Nearest to marriage: divorce, legate, standardized, disputing, money, fundraising, undernourished, her,
# Nearest to writers: science, births, actors, fiction, leonard, playwrights, bisexual, hugo,
# Nearest to institute: technology, humanities, jointly, institut, discouraged, diena, engineering, physiology,
# Nearest to placed: walls, supermarket, surrounded, vitriolic, draftsman, terraced, ceylon, passports,
# Nearest to mean: vitriolic, lon, average, antithesis, witt, equator, kiwi, cass,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.9905 0.4371 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.9717 0.4085 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 4.0329 0.4216 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.9268 0.3733 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 4.1501 0.4333 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 4.1023 0.4051 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8874 0.4048 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.9453 0.3969 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 4.0243 0.3648 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.9400 0.3834 sec/batch
# Nearest to s: norbert, perpendicular, singleton, frontline, smashed, lambeth, attitude, leiden,
# Nearest to while: yugoslavian, rosicrucians, ace, transitions, locate, stacked, skyline, overthrowing,
# Nearest to have: regionally, been, husband, rescued, draft, supplanted, enmity, sha,
# Nearest to such: wynne, polyglot, chordal, subjecting, proteg, touchstone, boldness, sounding,
# Nearest to one: minsky, periodic, six, eight, llc, zapata, nine, reproducing,
# Nearest to a: sided, trivia, terrorists, try, hospital, swap, square, stubs,
# Nearest to these: rh, diametrically, lump, reclassified, moth, initials, electors, carve,
# Nearest to during: northumberland, refinements, sheffield, dynasties, victory, precludes, pantheon, gibbon,
# Nearest to active: terri, relevant, thant, checking, passive, farmer, analogously, hart,
# Nearest to test: odds, program, pm, deliberately, isotropic, qana, excels, peano,
# Nearest to discovered: reynolds, solar, evidence, scientific, speculated, edible, radiative, assertion,
# Nearest to marriage: divorce, legate, disputing, standardized, fundraising, her, money, heir,
# Nearest to writers: births, science, actors, playwrights, hugo, bisexual, leonard, fiction,
# Nearest to institute: technology, humanities, jointly, discouraged, diena, management, institut, engineering,
# Nearest to placed: walls, supermarket, surrounded, vitriolic, draftsman, terraced, ceylon, stainless,
# Nearest to mean: vitriolic, lon, antithesis, average, witt, deceased, kiwi, equator,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 4.0716 0.3899 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.9888 0.3592 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.9294 0.3813 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 4.0064 0.3876 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 4.0845 0.3648 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.9457 0.4020 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 4.0078 0.3724 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.9892 0.4516 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.9449 0.4350 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 4.0096 0.3957 sec/batch
# Nearest to s: norbert, perpendicular, singleton, smashed, frontline, lambeth, attitude, leiden,
# Nearest to while: yugoslavian, rosicrucians, locate, stacked, transitions, ace, burdens, overthrowing,
# Nearest to have: regionally, been, rescued, husband, draft, sha, supplanted, enmity,
# Nearest to such: wynne, subjecting, polyglot, touchstone, chordal, boldness, pornographic, sounding,
# Nearest to one: periodic, eight, six, llc, minsky, estimates, developers, four,
# Nearest to a: sided, trivia, terrorists, hospital, try, archipelagoes, santer, swap,
# Nearest to these: rh, diametrically, lump, initials, electors, reclassified, moth, feynman,
# Nearest to during: northumberland, refinements, dynasties, precludes, sheffield, victory, pantheon, disadvantageous,
# Nearest to active: relevant, terri, thant, passive, teaching, checking, farmer, ram,
# Nearest to test: odds, program, peano, isotropic, deliberately, excels, qana, austrofascism,
# Nearest to discovered: solar, reynolds, evidence, scientific, edible, speculated, radiative, assertion,
# Nearest to marriage: divorce, standardized, legate, disputing, fundraising, money, heir, her,
# Nearest to writers: science, births, fiction, actors, hugo, playwrights, bisexual, authors,
# Nearest to institute: technology, humanities, jointly, discouraged, diena, management, institut, physiology,
# Nearest to placed: walls, supermarket, surrounded, vitriolic, draftsman, terraced, ceylon, imprint,
# Nearest to mean: vitriolic, lon, average, kiwi, witt, liffey, antithesis, nonexistence,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.9300 0.4084 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.9878 0.4075 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 4.0283 0.4175 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 4.1580 0.4201 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 4.1343 0.3632 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.9691 0.4038 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 4.0524 0.4047 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.9799 0.4082 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.9383 0.4235 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.9462 0.3983 sec/batch
# Nearest to s: perpendicular, norbert, singleton, lambeth, frontline, attitude, drops, gunmen,
# Nearest to while: yugoslavian, rosicrucians, burdens, locate, overthrowing, ace, stacked, transitions,
# Nearest to have: regionally, been, husband, rescued, draft, sha, enmity, supplanted,
# Nearest to such: wynne, chordal, subjecting, touchstone, polyglot, proteg, lay, boldness,
# Nearest to one: six, nine, eight, estimates, periodic, four, llc, rate,
# Nearest to a: sided, trivia, hospital, terrorists, try, swap, square, santer,
# Nearest to these: rh, diametrically, lump, reclassified, initials, moth, nutrient, electors,
# Nearest to during: northumberland, sheffield, refinements, dynasties, precludes, susan, victory, percent,
# Nearest to active: terri, relevant, passive, thant, checking, non, teaching, hart,
# Nearest to test: odds, program, deliberately, qana, pm, excels, isotropic, peano,
# Nearest to discovered: reynolds, solar, evidence, edible, scientific, speculated, assertion, bernhard,
# Nearest to marriage: divorce, standardized, legate, disputing, her, fundraising, heir, money,
# Nearest to writers: births, science, fiction, hugo, actors, winners, playwrights, authors,
# Nearest to institute: technology, humanities, jointly, discouraged, diena, management, institut, engineering,
# Nearest to placed: walls, supermarket, surrounded, draftsman, vitriolic, terraced, imprint, stainless,
# Nearest to mean: vitriolic, lon, average, kiwi, equator, witt, shots, liffey,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.9580 0.4132 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.9753 0.4036 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
